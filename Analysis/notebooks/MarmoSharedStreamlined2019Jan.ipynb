# %% [markdown]
# # Shared marmo models

# %%
# Import the rest
from __future__ import print_function
from __future__ import division

import sys

# sys.path.insert(0, '/home/dbutts/Code/')
sys.path.insert(0, 'C:\\Users\\Jake\\Documents\\')
sys.path.insert(0, 'C:\\Users\\Jake\\Documents\\NDN3')

import NDN3.NDNutils as NDNutils
# which_gpu = NDNutils.assign_gpu()
#NDNutils.setup_no_gpu()


import os
import h5py
import numpy as np
import tensorflow as tf
import scipy.io as sio           # importing matlab data
import matplotlib.pyplot as plt  # plotting
# %matplotlib inline
from copy import deepcopy

import time
import random
import NDN3.NDN as NDN
#import TNDN as TNDN
import NDN3.Utils.DanUtils as DU
import NDN3.Utils.NDNplot as NDNplot
output_dir = 'C:\\Users\\Jake\\Dropbox\\Projects\\NDN\\output_dir'
# output_dir = '/Users/dbutts/Code/PyPlay/tensorboard'
print(sys.version)
import sys
print(sys.path)
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = str(1)

print(output_dir)
# Out:
# 3.6.8 |Anaconda, Inc.| (default, Feb 21 2019, 18:30:04) [MSC v.1916 64 bit (AMD64)]
# ['C:\\Users\\Jake\\Documents\\NDN3', 'C:\\Users\\Jake\\Documents\\', 'C:\\Users\\Jake\\Documents\\NDN3', 'C:\\Users\\Jake\\Documents\\', 'C:\\Users\\Jake\\Documents\\NDN3', 'C:\\Users\\Jake\\Documents\\', 'C:\\Users\\Jake\\.conda\\envs\\NDN\\python36.zip', 'C:\\Users\\Jake\\.conda\\envs\\NDN\\DLLs', 'C:\\Users\\Jake\\.conda\\envs\\NDN\\lib', 'C:\\Users\\Jake\\.conda\\envs\\NDN', '', 'C:\\Users\\Jake\\.conda\\envs\\NDN\\lib\\site-packages', 'C:\\Users\\Jake\\.conda\\envs\\NDN\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Jake\\.ipython']
# C:\Users\Jake\Dropbox\Projects\NDN\output_dir

# %%
# Load Data
dirname = "C:\\Users\\Jake\\Dropbox\\Projects\\FreeViewing\\Data\\"
includeSaccades=True

matdat=sio.loadmat(dirname + 'L20191231_GaborL.mat')
frameTimes1 = matdat['frameTimes'].copy()
# stim1 = matdat['stim'].copy()
Robs1 = matdat['Robs'].copy()
valdat1 = matdat['valdata'].copy()
labels1 = matdat['labels'].copy()
if includeSaccades:
    valid1 = np.intersect1d(np.where(valdat1[:,0] == 1)[0], np.where(labels1[:,0] == 1)[0])
else:
    valid1 = np.intersect1d(np.where(valdat1[:,0] == 1)[0], np.where(np.logical_or(labels1[:,0]==2,labels1[:,0]==1))[0])
    
slist1 = matdat['slist'].astype(int)
dt = matdat['dt'][0][0]
NY = matdat['NX'][0][0].astype(int)
ets1 = matdat['eyeAtFrame']

matdat=sio.loadmat(dirname + 'L20191231_Gabor_Cstim.mat')
stim1 = matdat['Cstim'].copy()

NP = stim1.shape[1]
NX = (NP//NY).astype(int)
NT1,NCfull = Robs1.shape


matdat = sio.loadmat(dirname + 'L20191231_GratingL.mat')
frameTimes2 = matdat['frameTimes'].copy()
# stim2 = matdat['stim'].copy()
Robs2 = matdat['Robs'].copy()
valdat2 = matdat['valdata'].copy()
labels2 = matdat['labels'].copy()
# valid2 = np.intersect1d(np.where(valdat2[:,0] == 1)[0], np.where(labels2[:,0] == 1)[0])
if includeSaccades:
    valid2 = np.intersect1d(np.where(valdat2[:,0] == 1)[0], np.where(labels2[:,0] == 1)[0])
else:
    valid2 = np.intersect1d(np.where(valdat2[:,0] == 1)[0], np.where(np.logical_or(labels2[:,0]==2,labels2[:,0]==1))[0])
    
slist2 = matdat['slist'].astype(int)
ets2 = matdat['eyeAtFrame']
NT2 = Robs2.shape[0]

matdat = sio.loadmat(dirname + 'L20191231_Grating_Cstim.mat')
stim2 = matdat['Cstim'].copy()

print(NT1, NT2, NCfull,'|', NX, NY)
# Out:
# 96984 77295 61 | 40 40

# %%
# Determine valid indices based on eye position
valid_eye_rad = 5.0  # degrees
pixPerDeg = 37.50476617061
# Radial eye position (in degrees)
er1s = np.divide(np.sqrt(np.add(np.square(ets1[:,0]-640), np.square(ets1[:,1]-360))), pixPerDeg)
er2s = np.divide(np.sqrt(np.add(np.square(ets2[:,0]-640), np.square(ets2[:,1]-360))), pixPerDeg)
#er3s = np.divide(np.sqrt(np.add(np.square(ets3[:,0]-640), np.square(ets3[:,1]-360))), pixPerDeg)

# Selection of valid indices where eye tracker estimated to be valid
eyeval1 = np.intersect1d(valid1, np.where(er1s < valid_eye_rad)[0])
eyeval2 = np.intersect1d(valid2, np.where(er2s < valid_eye_rad)[0])
#eyeval3 = np.intersect1d(valid3, np.where(er3s < valid_eye_rad)[0])

# Make train and test inds for each trial
Uinds1, Xinds1 = NDNutils.generate_xv_folds(len(eyeval1), num_blocks=2)
Uinds2, Xinds2 = NDNutils.generate_xv_folds(len(eyeval2), num_blocks=2)
#Uinds3, Xinds3 = NDNutils.generate_xv_folds(len(eyeval3), num_blocks=2)

# %%
### Concatenate data: 2 conditions
spaceL = 60
Sspacer = np.zeros([spaceL, NP], dtype='float32')
Rspacer = np.zeros([spaceL, NCfull], dtype='float32')

Tspacer = np.zeros([spaceL, 1], dtype='float32')
frameTimesAll = np.concatenate((frameTimes1, Tspacer, frameTimes2), axis=0)

RobsAll = np.concatenate( (Robs1, Rspacer, Robs2), axis=0)
# Assemble valid data and translate Ui's and Xi's 
valdata = np.concatenate( (eyeval1, eyeval2+NT1+spaceL), axis=0 )
Ui1, Xi1 = Uinds1.copy(), Xinds1.copy()
Ui2, Xi2 = Uinds2.copy()+len(eyeval1), Xinds2.copy()+len(eyeval1)
Ui = np.concatenate((Ui1, Ui2), axis=0)
Xi = np.concatenate((Xi1, Xi2), axis=0)

stim = np.concatenate( (stim1.copy(), Sspacer.copy(), stim2.copy()), axis=0)
stim_norm = np.std(stim[valdata,:], axis=0)
stim = np.divide( stim, stim_norm)

NTfull = stim.shape[0]
NT = valdata.shape[0]

# Process saccades -- just store sacc offsets as delta functions
sac_on, sac_off = np.zeros([NTfull,1], dtype='float32'), np.zeros([NTfull,1], dtype='float32')
for nn in range(slist1.shape[0]):
    sac_on[slist1[nn,0]-1] = 1.0
    sac_off[slist1[nn,1]-1] = 1.0
for nn in range(slist2.shape[0]):
    sac_on[slist2[nn,0]-1+NT1+spaceL] = 1.0
    sac_off[slist2[nn,1]-1+NT1+spaceL] = 1.0
    
ex = np.concatenate( (ets1[:,0].copy(), Sspacer[:,0], ets2[:,0].copy()), axis=0)-640
ey = np.concatenate( (ets1[:,1].copy(), Sspacer[:,0], ets2[:,1].copy()), axis=0)-360
print("Data size: %d (%d valid)"%(NTfull, NT) )
print("Train: %6d (%5d+%5d)"%(len(Ui), len(Ui1), len(Ui2)))
print("Test:  %6d (%5d+%5d)"%(len(Xi), len(Xi1), len(Xi2)))
# Out:
# Data size: 174339 (99389 valid)
# Train:  79511 (41388+38123)
# Test:   19878 (10348+ 9530)

# %%
# Data adjustment
Nspks = np.sum(RobsAll[valdata,:],axis=0)
valcell = np.where(Nspks > 500)[0]
NC = len(valcell)
Robs = RobsAll[:,valcell]
print(NC, 'selected')
# Out:
# 58 selected

# %%
#sio.savemat(dirname+'Data/valcell1231.mat', {'valcell':valcell})

# %%
adam_params = NDN.NDN.optimizer_defaults(opt_params={'use_gpu': True}, learning_alg='adam')

early_stopping = 100

adam_params['batch_size'] = 1000 #NT // 50
adam_params['display'] = 30
adam_params['epochs_training'] = early_stopping * 100
adam_params['run_diagnostics'] = False

adam_params['epsilon'] = 1e-8
adam_params['early_stop'] = early_stopping
adam_params['early_stop_mode'] = 1
#adam_params['data_pipe_type'] = 'iterator'
adam_params['data_pipe_type'] = 'data_as_var'
adam_params['learning_rate'] = 1e-3
#adam_params['epochs_summary'] = 5
for d in adam_params:
    print("%20s:\t %s" %(d, adam_params[d]))

lbfgs_params = NDN.NDN.optimizer_defaults(opt_params={'use_gpu': True, 'display': True}, learning_alg='lbfgs')
lbfgs_params['maxiter'] = 1000
print('\nLBFGS:')
for d in lbfgs_params:
    print("%20s:\t %s" %(d, lbfgs_params[d]))

adam_loc = adam_params.copy()
#adam_loc['batch_size'] = len(valtot)//200
adam_loc['early_stop'] = 100
adam_locX = adam_loc.copy()
adam_locX['early_stop_mode'] = 2
# Out:
#              use_gpu:	 True
#              display:	 30
#       data_pipe_type:	 data_as_var
#    poisson_unit_norm:	 None
#          epochs_ckpt:	 None
#        learning_rate:	 0.001
#           batch_size:	 1000
#      epochs_training:	 10000
#      early_stop_mode:	 1
#       epochs_summary:	 None
#           early_stop:	 100
#                beta1:	 0.9
#                beta2:	 0.999
#              epsilon:	 1e-08
#      run_diagnostics:	 False
#
# LBFGS:
#              use_gpu:	 True
#              display:	 True
#       data_pipe_type:	 data_as_var
#    poisson_unit_norm:	 None
#          epochs_ckpt:	 None
#              maxiter:	 1000
#             func_tol:	 2.220446049250313e-09
#             grad_tol:	 1e-05
#                  eps:	 1e-08
#           batch_size:	 None

# %% [markdown]
# ## Cropping

# %%
def crop_indx( Loriginal, xrange, yrange):
    # brain-dead way to crop things with space indexed by one dim
    # Note I'm calling x the horizontal dimension (as plotted by python and y the vertical direction)
    # Also assuming everything square
    indxs = []
    for nn in range(len(yrange)):
        indxs = np.concatenate((indxs, np.add(xrange,yrange[nn]*Loriginal)))
    return indxs.astype('int')

# %%
# Full stim -- to be replaced
num_lags = 10
Xstim = NDNutils.create_time_embedding( stim, [num_lags, NX, NX], tent_spacing=1 )[valdata,:]

# %%
# Shift responses to take out first lag (just why bother with it)
Robs = NDNutils.shift_mat_zpad(RobsAll[:,valcell], -1, dim=0)
# STAs
stas = np.reshape(np.matmul(np.transpose(Xstim),Robs[valdata,:]), [NP,num_lags, NC])/len(valdata)
np.mean(np.max(abs(stas), axis=0))
# Out:
# 0.010278647331332994

# %%
DU.subplot_setup(6,10)
for cc in range(NC):
    plt.subplot(6,10,cc+1)
    #plt.plot(np.transpose(stas[:,:,cc]))
    bestlag = np.argmax(np.max(abs(stas[:,:,cc]),axis=0))
    plt.imshow(np.reshape(stas[:,bestlag,cc], [NX, NY]), cmap='gray')  #RdBu_r 
               #vmin=-np.max(abs(stas[:,:,cc])), vmax=np.max(abs(stas[:,:,cc])))
    plt.title(str(bestlag)+' cell'+str(cc),)
plt.show()

# %%
sumdensity = np.zeros([NX*NX])
for cc in range(NC):
    bestlag = np.argmax(np.max(abs(stas[:,:,cc]),axis=0))
    sumdensity += abs(stas[:,bestlag,cc])
plt.imshow(np.reshape(sumdensity, [NX,NX]))
plt.show()

# %%
Cindx = crop_indx( NX, range(11, 35), range(15,39) )
NX2 = np.sqrt(len(Cindx)).astype(int)
print(NX2)
plt.imshow(np.reshape(sumdensity[Cindx],[NX2,NX2]))
plt.show()
# Out:
# 24

# %%
# Make smaller Xstim (replacing larger)
num_lags = 10
Xstim = NDNutils.create_time_embedding( stim[:, Cindx], [num_lags, NX2, NX2], tent_spacing=1 )[valdata,:]

# %% [markdown]
# ## Shared NIMs

# %%
# Regularization parameters arrived at though initial playing (on different notebook)
Greg0 = None
Mreg0 = 1e-6
L1reg0 = 1e-5

L1reg = 0.002
XTreg = 0.05
Mreg = 0.1 
Greg = 0.1
num_subs = 36

# %%
# Best configuation of shared NIM (roughly)

nim_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, NC], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2],
    normalization=[1,-1], act_funcs=['relu', 'softplus'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0], 'max':[None,Mreg0]})

snim0 = NDN.NDN( nim_par, noise_dist='poisson' )
_ = snim0.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
snim0.set_regularization('glocal', Greg, layer_target=0)
snim0.set_regularization('l1', L1reg, layer_target=0)
snim0.set_regularization('max', Mreg, layer_target=1)
_ = snim0.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs1 = snim0.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs1n = snim0.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs1), np.mean(LLs1n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (softplus):  	[E58/I0] N+
# Epoch 0000:  avg train cost =     4.2153,  avg test cost =     4.3238,  reg penalty =     0.3647
# Epoch 0029:  avg train cost =     3.2909,  avg test cost =     3.5186,  reg penalty =     0.0786
# Epoch 0059:  avg train cost =     3.2536,  avg test cost =     3.4462,  reg penalty =     0.0690
# Epoch 0089:  avg train cost =     3.2436,  avg test cost =     3.4219,  reg penalty =     0.0630
# Epoch 0119:  avg train cost =     3.2387,  avg test cost =     3.4149,  reg penalty =     0.0602
# Epoch 0149:  avg train cost =     3.2351,  avg test cost =     3.4096,  reg penalty =     0.0589
# Epoch 0179:  avg train cost =     3.2319,  avg test cost =     3.4076,  reg penalty =     0.0583
# Epoch 0209:  avg train cost =     3.2289,  avg test cost =     3.4065,  reg penalty =     0.0579
# Epoch 0239:  avg train cost =     3.2264,  avg test cost =     3.4064,  reg penalty =     0.0578
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 264,  end cost: 201.193524
#      ---> best epoch: 263,  best cost: 200.833604
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2622,  avg test cost =     3.4203,  reg penalty =     0.1643
# Epoch 0029:  avg train cost =     3.2220,  avg test cost =     3.3413,  reg penalty =     0.1274
# Epoch 0059:  avg train cost =     3.2205,  avg test cost =     3.3323,  reg penalty =     0.1202
# Epoch 0089:  avg train cost =     3.2183,  avg test cost =     3.3239,  reg penalty =     0.1170
# Epoch 0119:  avg train cost =     3.2158,  avg test cost =     3.3216,  reg penalty =     0.1153
# Epoch 0149:  avg train cost =     3.2150,  avg test cost =     3.3184,  reg penalty =     0.1144
# Epoch 0179:  avg train cost =     3.2137,  avg test cost =     3.3180,  reg penalty =     0.1137
# Epoch 0209:  avg train cost =     3.2135,  avg test cost =     3.3170,  reg penalty =     0.1133
# Epoch 0239:  avg train cost =     3.2132,  avg test cost =     3.3166,  reg penalty =     0.1129
# Epoch 0269:  avg train cost =     3.2124,  avg test cost =     3.3156,  reg penalty =     0.1127
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 295,  end cost: 198.984703
#      ---> best epoch: 243,  best cost: 198.815136
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.3149738 0.2544877

# %%
snim0.save_model(dirname+'pkls\\d1231snim0.pkl')

# %%
# Best configuation of shared NIM (roughly)
num_subs = 36
nim_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, NC], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2],
    normalization=[1,-1], act_funcs=['relu', 'softplus'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0], 'max':[None,Mreg0]})

snim0 = NDN.NDN( nim_par, noise_dist='poisson' )
_ = snim0.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
# put on localization and max penalty
snim0.set_regularization('glocal', Greg, layer_target=0)
snim0.set_regularization('max', Mreg, layer_target=1)
_ = snim0.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
# Now apply l1
snim0.set_regularization('l1', L1reg, layer_target=0)
_ = snim0.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs1 = snim0.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs1n = snim0.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs1), np.mean(LLs1n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (softplus):  	[E58/I0] N+
# Epoch 0000:  avg train cost =     4.1813,  avg test cost =     4.2951,  reg penalty =     0.3895
# Epoch 0029:  avg train cost =     3.2834,  avg test cost =     3.5127,  reg penalty =     0.0785
# Epoch 0059:  avg train cost =     3.2472,  avg test cost =     3.4435,  reg penalty =     0.0694
# Epoch 0089:  avg train cost =     3.2366,  avg test cost =     3.4211,  reg penalty =     0.0637
# Epoch 0119:  avg train cost =     3.2306,  avg test cost =     3.4162,  reg penalty =     0.0609
# Epoch 0149:  avg train cost =     3.2269,  avg test cost =     3.4128,  reg penalty =     0.0596
# Epoch 0179:  avg train cost =     3.2236,  avg test cost =     3.4111,  reg penalty =     0.0589
# Epoch 0209:  avg train cost =     3.2208,  avg test cost =     3.4129,  reg penalty =     0.0587
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 222,  end cost: 201.498682
#      ---> best epoch: 147,  best cost: 201.245957
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2633,  avg test cost =     3.4265,  reg penalty =     0.0985
# Epoch 0029:  avg train cost =     3.2155,  avg test cost =     3.3530,  reg penalty =     0.0786
# Epoch 0059:  avg train cost =     3.2116,  avg test cost =     3.3450,  reg penalty =     0.0761
# Epoch 0089:  avg train cost =     3.2081,  avg test cost =     3.3386,  reg penalty =     0.0751
# Epoch 0119:  avg train cost =     3.2053,  avg test cost =     3.3372,  reg penalty =     0.0746
# Epoch 0149:  avg train cost =     3.2041,  avg test cost =     3.3350,  reg penalty =     0.0743
# Epoch 0179:  avg train cost =     3.2031,  avg test cost =     3.3340,  reg penalty =     0.0742
# Epoch 0209:  avg train cost =     3.2019,  avg test cost =     3.3342,  reg penalty =     0.0743
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 222,  end cost: 197.755191
#      ---> best epoch: 202,  best cost: 197.585171
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2375,  avg test cost =     3.3564,  reg penalty =     0.1322
# Epoch 0029:  avg train cost =     3.2096,  avg test cost =     3.3135,  reg penalty =     0.1152
# Epoch 0059:  avg train cost =     3.2067,  avg test cost =     3.3138,  reg penalty =     0.1134
# Epoch 0089:  avg train cost =     3.2040,  avg test cost =     3.3108,  reg penalty =     0.1130
# Epoch 0119:  avg train cost =     3.2011,  avg test cost =     3.3085,  reg penalty =     0.1126
# Epoch 0149:  avg train cost =     3.2005,  avg test cost =     3.3073,  reg penalty =     0.1125
# Epoch 0179:  avg train cost =     3.1994,  avg test cost =     3.3066,  reg penalty =     0.1124
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 198,  end cost: 198.466941
#      ---> best epoch: 195,  best cost: 198.225300
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.3052418 0.26421982

# %%
snim0.save_model(dirname+'pkls/d1231snim0.pkl')

# %%
# or load model
fname = dirname + "pkls\\d1231snim0.pkl"
snim0 = NDN.NDN.load_model(fname)

DU.plot_filters(snim0)
# Out:
# Model pickled to /home/dbutts/Marmo/pkls/d1231snim0.pkl

# %%
ws = snim0.networks[0].layers[1].weights.copy()
ws[range(18,36),:] *= -1
plt.imshow(ws, cmap='bwr', vmin=-np.max(abs(ws)), vmax=np.max(abs(ws)))
plt.show()
# any patterns of connectivity (hard to say)
plt.plot(np.sum(np.maximum(ws[:,range(58//2)],0), axis=0),'b')
plt.plot(np.sum(np.maximum(ws[:,range(58//2,58)],0), axis=0),'c')
plt.plot(np.sum(np.minimum(ws[:,range(58//2)],0), axis=0),'r')
plt.plot(np.sum(np.minimum(ws[:,range(58//2,58)],0), axis=0),'m')
plt.show()

# %% [markdown]
# ## Deeper stim-only models

# %%
num_subs = 36
num_hid = 36

ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid, NC], 
    layer_types=['normal','normal','normal'], ei_layers=[num_subs//2, num_hid//2],
    normalization=[1,1, -1], act_funcs=['relu', 'relu', 'softplus'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0], 'max':[None,None,Mreg0]})

ndn30 = NDN.NDN( ndn_par, noise_dist='poisson' )
_ = ndn30.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
ndn30.set_regularization('glocal', Greg, layer_target=0)
ndn30.set_regularization('l1', L1reg, layer_target=0)
ndn30.set_regularization('max', Mreg, layer_target=2)
_ = ndn30.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs2 = ndn30.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs2n = ndn30.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs2), np.mean(LLs2n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (relu):  	[E18/I18] N+
# 2: normal (softplus):  	[E58/I0] N+
# Epoch 0000:  avg train cost =     3.9324,  avg test cost =     4.0670,  reg penalty =     0.2375
# Epoch 0029:  avg train cost =     3.1947,  avg test cost =     3.4251,  reg penalty =     0.0603
# Epoch 0059:  avg train cost =     3.1675,  avg test cost =     3.4033,  reg penalty =     0.0563
# Epoch 0089:  avg train cost =     3.1545,  avg test cost =     3.4034,  reg penalty =     0.0559
# Epoch 0119:  avg train cost =     3.1465,  avg test cost =     3.4162,  reg penalty =     0.0560
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 137,  end cost: 201.299073
#      ---> best epoch: 61,  best cost: 200.280531
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2171,  avg test cost =     3.4001,  reg penalty =     0.1768
# Epoch 0029:  avg train cost =     3.1701,  avg test cost =     3.3211,  reg penalty =     0.1320
# Epoch 0059:  avg train cost =     3.1596,  avg test cost =     3.3172,  reg penalty =     0.1264
# Epoch 0089:  avg train cost =     3.1533,  avg test cost =     3.3162,  reg penalty =     0.1248
# Epoch 0119:  avg train cost =     3.1475,  avg test cost =     3.3187,  reg penalty =     0.1244
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 145,  end cost: 200.076857
#      ---> best epoch: 134,  best cost: 199.454939
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.314545 0.25470924

# %% [markdown]
# ### Scaffold

# %%
# Best regularization arrived at
Greg0 = None
Mreg0 = 1e-6
L1reg0 = 1e-5

L1reg = 0.003 # 0.01 optimal but RFs too sparse
XTreg = 0.01 # from 0.05
MIreg = 0.1
MSCreg = 10.0
Greg = 0.1

## SCAFFOLD
num_subs = 36
num_hid = 24

# %%
# Scaffold
ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2, num_hid//2],
    normalization=[1,1], act_funcs=['relu', 'relu'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=True,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True
side2 = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
_ = side2.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
side2.set_regularization('glocal', Greg, layer_target=0)
side2.set_regularization('l1', L1reg, layer_target=0)
side2.set_regularization('max', MIreg, ffnet_target=0, layer_target=1)
side2.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
side2b = side2.copy_model()
_ = side2b.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs2 = side2b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs2n = side2b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs2), np.mean(LLs2n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (relu):  	[E12/I12] N+
# 0: normal (softplus):  	[E58/I0] N
# Epoch 0000:  avg train cost =     4.1116,  avg test cost =     4.2339,  reg penalty =     0.1083
# Epoch 0029:  avg train cost =     3.1635,  avg test cost =     3.4512,  reg penalty =     0.0376
# Epoch 0059:  avg train cost =     3.1149,  avg test cost =     3.4408,  reg penalty =     0.0383
# Epoch 0089:  avg train cost =     3.0960,  avg test cost =     3.4345,  reg penalty =     0.0393
# Epoch 0119:  avg train cost =     3.0860,  avg test cost =     3.4383,  reg penalty =     0.0400
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 135,  end cost: 201.933484
#      ---> best epoch: 94,  best cost: 201.280995
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.1928,  avg test cost =     3.4080,  reg penalty =     1.4890
# Epoch 0029:  avg train cost =     3.2045,  avg test cost =     3.2797,  reg penalty =     0.1395
# Epoch 0059:  avg train cost =     3.2039,  avg test cost =     3.2666,  reg penalty =     0.1276
# Epoch 0089:  avg train cost =     3.2023,  avg test cost =     3.2575,  reg penalty =     0.1233
# Epoch 0119:  avg train cost =     3.2017,  avg test cost =     3.2573,  reg penalty =     0.1185
# Epoch 0149:  avg train cost =     3.2012,  avg test cost =     3.2573,  reg penalty =     0.1163
# Epoch 0179:  avg train cost =     3.2015,  avg test cost =     3.2566,  reg penalty =     0.1149
# Epoch 0209:  avg train cost =     3.2002,  avg test cost =     3.2560,  reg penalty =     0.1143
# Epoch 0239:  avg train cost =     3.2001,  avg test cost =     3.2547,  reg penalty =     0.1136
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 247,  end cost: 195.592630
#      ---> best epoch: 227,  best cost: 195.358061
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.2545016 0.31495985

# %%
side2b.save_model(dirname+'pkls/d1231csn0.pkl')

# %%
# or load model
fname = dirname + "pkls\\d1231csn0.pkl"
side2b = NDN.NDN.load_model(fname)

DU.plot_filters(side2b)

# %%
plot_3dfilters(side2b)
DU.scaffold_nonconv_plot(side2b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1240f8ccb8ee> in <module>
# ----> 1 plot_3dfilters(side2b)
#       2 DU.scaffold_nonconv_plot(side2b)
#
# NameError: name 'plot_3dfilters' is not defined

# %%
## Add extra step
num_subs = 36
num_hid = 24

ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2, num_hid//2],
    normalization=[1,1], act_funcs=['relu', 'relu'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=True,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True
side2 = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
_ = side2.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
side2.set_regularization('glocal', Greg, layer_target=0)
side2.set_regularization('max', MIreg, ffnet_target=0, layer_target=1)
side2.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
_ = side2.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

side2.set_regularization('l1', L1reg, layer_target=0)
side2b = side2.copy_model()
_ = side2b.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs2 = side2b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs2n = side2b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs2), np.mean(LLs2n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (relu):  	[E12/I12] N+
# 0: normal (softplus):  	[E58/I0] N
# Epoch 0000:  avg train cost =     4.1692,  avg test cost =     4.2560,  reg penalty =     0.3404
# Epoch 0029:  avg train cost =     3.2054,  avg test cost =     3.4317,  reg penalty =     0.0685
# Epoch 0059:  avg train cost =     3.1702,  avg test cost =     3.4011,  reg penalty =     0.0640
# Epoch 0089:  avg train cost =     3.1549,  avg test cost =     3.3996,  reg penalty =     0.0637
# Epoch 0119:  avg train cost =     3.1444,  avg test cost =     3.3972,  reg penalty =     0.0638
# Epoch 0149:  avg train cost =     3.1374,  avg test cost =     3.3970,  reg penalty =     0.0638
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 169,  end cost: 200.821464
#      ---> best epoch: 142,  best cost: 200.494584
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2286,  avg test cost =     3.3756,  reg penalty =     1.1517
# Epoch 0029:  avg train cost =     3.2182,  avg test cost =     3.2819,  reg penalty =     0.0980
# Epoch 0059:  avg train cost =     3.2158,  avg test cost =     3.2679,  reg penalty =     0.0878
# Epoch 0089:  avg train cost =     3.2141,  avg test cost =     3.2637,  reg penalty =     0.0834
# Epoch 0119:  avg train cost =     3.2121,  avg test cost =     3.2619,  reg penalty =     0.0809
# Epoch 0149:  avg train cost =     3.2104,  avg test cost =     3.2620,  reg penalty =     0.0799
# Epoch 0179:  avg train cost =     3.2106,  avg test cost =     3.2607,  reg penalty =     0.0788
# Epoch 0209:  avg train cost =     3.2090,  avg test cost =     3.2617,  reg penalty =     0.0788
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 193.826154
#      ---> best epoch: 216,  best cost: 193.579064
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2283,  avg test cost =     3.2612,  reg penalty =     0.1259
# Epoch 0029:  avg train cost =     3.2154,  avg test cost =     3.2458,  reg penalty =     0.1077
# Epoch 0059:  avg train cost =     3.2151,  avg test cost =     3.2429,  reg penalty =     0.1042
# Epoch 0089:  avg train cost =     3.2147,  avg test cost =     3.2439,  reg penalty =     0.1030
# Epoch 0119:  avg train cost =     3.2134,  avg test cost =     3.2440,  reg penalty =     0.1026
# Epoch 0149:  avg train cost =     3.2128,  avg test cost =     3.2440,  reg penalty =     0.1023
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 176,  end cost: 194.144518
#      ---> best epoch: 168,  best cost: 193.917312
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.2413409 0.32791305

# %%
# Check L1 regularization in this context
rvals = [1e-6, 1e-4, 0.001, 0.01, 0.1, 1.0]
LLsL, RmodsL = NDNutils.reg_path(
    ndn_mod=side2, input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi,
    reg_type='l1', reg_vals=rvals, ffnet_target=0, layer_target=0, opt_params=adam_params)
plt.plot(LLsL,'b')
plt.show()# Check d2xt as well (once L1 optimized -- seems a little smooth)
# Out:
# 0 (l1 = 1e-06): 3.255961
# 1 (l1 = 0.0001): 3.2554898
# 2 (l1 = 0.001): 3.248769
# 3 (l1 = 0.01): 3.2379928
# 4 (l1 = 0.1): 3.290161
# 5 (l1 = 1.0): 3.3672109

# %%
# Check L1 regularization in this context
rvals = [1e-6, 1e-4, 0.001, 0.01, 0.1, 1.0]
LLsX, RmodsX = NDNutils.reg_path(
    ndn_mod=side2, input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi,
    reg_type='d2xt', reg_vals=rvals, ffnet_target=0, layer_target=0, opt_params=adam_params)
plt.plot(LLsX,'g')
plt.show()# Check d2xt as well (once L1 optimized -- seems a little smooth)
# Out:
# 0 (d2xt = 1e-06): 3.25171
# 1 (d2xt = 0.0001): 3.251106
# 2 (d2xt = 0.001): 3.2500086
# 3 (d2xt = 0.01): 3.2430148
# 4 (d2xt = 0.1): 3.248251
# 5 (d2xt = 1.0): 3.3035216

# %%
## TWO STAGE -- get subunit connectivity and then beef up L1 at the end
plot_3dfilters(RmodsL[3])
#DU.scaffold_nonconv_plot(side2b)

# %%
rvals = [1e-6, 1e-4, 0.001, 0.01, 0.1, 1.0]
LLsM, RmodsM = NDNutils.reg_path(
    ndn_mod=sideX2, input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi,
    reg_type='max', reg_vals=rvals, ffnet_target=1, layer_target=0, opt_params=adam_params)
plt.plot(LLsM,'b')
plt.show()
# Out:
# 0 (max = 1e-06): 3.3586128
# 1 (max = 0.0001): 3.3535628
# 2 (max = 0.001): 3.3534663
# 3 (max = 0.01): 3.3444579
# 4 (max = 0.1): 3.3253663
# 5 (max = 1.0): 3.2859619

# %%
rvals = [1.0, 2.0,4.0,10.0]
LLsM2, RmodsM2 = NDNutils.reg_path(
    ndn_mod=sideX2, input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi,
    reg_type='max', reg_vals=rvals, ffnet_target=1, layer_target=0, opt_params=adam_params)
plt.plot(LLsM2,'b')
plt.show()
# Out:
# 0 (max = 1.0): 3.2859619
# 1 (max = 2.0): 3.2811167
# 2 (max = 4.0): 3.2756348
# 3 (max = 10.0): 3.2699556

# %%
def plot_pop_subunit_weights(ws, num_inh=None):
    ws_play = deepcopy(ws)
    Ndim, Nsub = ws.shape
    if num_inh is not None:
        ws_play[range(Ndim-num_inh, Ndim),:] *= -1
    m = np.max(abs(ws_play))
    plt.imshow(ws_play, cmap='bwr', vmin=-m, vmax=m)

# %%
# Weights between first and second layer
plot_pop_subunit_weights(RmodsM2[-1].networks[0].layers[1].weights, 12)
# Weights to output
DU.scaffold_nonconv_plot(RmodsM2[-1])

# %%
# Deeper model
num_subs = 36
num_hid = 24

ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid, num_hid], 
    layer_types=['normal','normal','normal'], ei_layers=[num_subs//2, num_hid//2, num_hid//2],
    normalization=[1,1,1], act_funcs=['relu', 'relu', 'relu'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=True,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True
side3 = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
_ = side3.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
side3.set_regularization('glocal', Greg, layer_target=0)
side3.set_regularization('max', MIreg, ffnet_target=0, layer_target=1)
side3.set_regularization('max', MIreg, ffnet_target=0, layer_target=2)
side3.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
_ = side3.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

side3.set_regularization('l1', L1reg, layer_target=0)
side3b = side3.copy_model()
_ = side3b.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

LLs3 = side3b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLs3n = side3b.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs2), np.mean(LLs2n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (relu):  	[E12/I12] N+
# 2: normal (relu):  	[E12/I12] N+
# 0: normal (softplus):  	[E58/I0] N
# Epoch 0000:  avg train cost =     4.0637,  avg test cost =     4.1672,  reg penalty =     0.1118
# Epoch 0029:  avg train cost =     3.1329,  avg test cost =     3.3925,  reg penalty =     0.0348
# Epoch 0059:  avg train cost =     3.0945,  avg test cost =     3.4026,  reg penalty =     0.0366
# Epoch 0089:  avg train cost =     3.0771,  avg test cost =     3.4093,  reg penalty =     0.0380
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 111,  end cost: 200.271455
#      ---> best epoch: 23,  best cost: 198.722069
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2244,  avg test cost =     3.3642,  reg penalty =     1.3871
# Epoch 0029:  avg train cost =     3.1717,  avg test cost =     3.3007,  reg penalty =     0.0829
# Epoch 0059:  avg train cost =     3.1573,  avg test cost =     3.3002,  reg penalty =     0.0811
# Epoch 0089:  avg train cost =     3.1499,  avg test cost =     3.2990,  reg penalty =     0.0814
# Epoch 0119:  avg train cost =     3.1445,  avg test cost =     3.3031,  reg penalty =     0.0820
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 126,  end cost: 196.437567
#      ---> best epoch: 57,  best cost: 195.883431
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.1925,  avg test cost =     3.2951,  reg penalty =     0.1619
# Epoch 0029:  avg train cost =     3.1706,  avg test cost =     3.2731,  reg penalty =     0.1344
# Epoch 0059:  avg train cost =     3.1669,  avg test cost =     3.2733,  reg penalty =     0.1308
# Epoch 0089:  avg train cost =     3.1640,  avg test cost =     3.2728,  reg penalty =     0.1298
# Epoch 0119:  avg train cost =     3.1613,  avg test cost =     3.2765,  reg penalty =     0.1295
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 126,  end cost: 197.644742
#      ---> best epoch: 101,  best cost: 197.260135
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 3.2493193 0.3199348

# %%
#DU.plot_3dfilters(side3b)
DU.scaffold_nonconv_plot(side3b)

# %% [markdown]
# No better than with two

# %%
## ASSUME FIRST LAYER 
sublist=[16, 24, 32, 40, 48, 60]
num_hid = 48

Niter = len(sublist)
LLsSCsubs = np.zeros(Niter)
SCsub_mods = []

side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=False,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True

for nn in range(Niter):

    ndn_par = NDNutils.ffnetwork_params( 
        input_dims=[1,NX2,NX2, num_lags], layer_sizes=[sublist[nn], num_hid], 
        layer_types=['normal','normal'], ei_layers=[sublist[nn]//2, num_hid//2],
        normalization=[1,1], act_funcs=['relu', 'relu'], verbose=False,
        reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
    side_iter = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
    side_iter.set_regularization('glocal', Greg, layer_target=0)
    side_iter.set_regularization('l1', L1reg, layer_target=0)
    side_iter.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

    LLs = side_iter.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
    LLsSCsubs[nn] = np.mean(LLs)
    SCsub_mods.append(side_iter.copy_model())
    print( sublist[nn], LLsSCsubs)
# Out:
# Epoch 0000:  avg train cost =     4.0775,  avg test cost =     4.1883,  reg penalty =     0.0848
# Epoch 0029:  avg train cost =     3.2523,  avg test cost =     3.4224,  reg penalty =     0.0490
# Epoch 0059:  avg train cost =     3.2310,  avg test cost =     3.3993,  reg penalty =     0.0442
# Epoch 0089:  avg train cost =     3.2211,  avg test cost =     3.3918,  reg penalty =     0.0433
# Epoch 0119:  avg train cost =     3.2150,  avg test cost =     3.3956,  reg penalty =     0.0432
# Epoch 0149:  avg train cost =     3.2116,  avg test cost =     3.3953,  reg penalty =     0.0431
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 164,  end cost: 199.484206
#      ---> best epoch: 134,  best cost: 199.143604
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2824,  avg test cost =     3.4054,  reg penalty =     1.6069
# Epoch 0029:  avg train cost =     3.2571,  avg test cost =     3.3181,  reg penalty =     0.0818
# Epoch 0059:  avg train cost =     3.2496,  avg test cost =     3.2969,  reg penalty =     0.0739
# Epoch 0089:  avg train cost =     3.2462,  avg test cost =     3.2881,  reg penalty =     0.0700
# Epoch 0119:  avg train cost =     3.2437,  avg test cost =     3.2868,  reg penalty =     0.0682
# Epoch 0149:  avg train cost =     3.2414,  avg test cost =     3.2822,  reg penalty =     0.0667
# Epoch 0179:  avg train cost =     3.2415,  avg test cost =     3.2803,  reg penalty =     0.0653
# Epoch 0209:  avg train cost =     3.2397,  avg test cost =     3.2800,  reg penalty =     0.0647
# Epoch 0239:  avg train cost =     3.2399,  avg test cost =     3.2805,  reg penalty =     0.0643
# Epoch 0269:  avg train cost =     3.2393,  avg test cost =     3.2778,  reg penalty =     0.0636
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 290,  end cost: 194.062946
#      ---> best epoch: 286,  best cost: 193.729634
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 16 [3.27677703 0.         0.         0.         0.         0.        ]
# Epoch 0000:  avg train cost =     4.1140,  avg test cost =     4.2292,  reg penalty =     0.1774
# Epoch 0029:  avg train cost =     3.2196,  avg test cost =     3.4000,  reg penalty =     0.0563
# Epoch 0059:  avg train cost =     3.1905,  avg test cost =     3.3756,  reg penalty =     0.0520
# Epoch 0089:  avg train cost =     3.1779,  avg test cost =     3.3709,  reg penalty =     0.0516
# Epoch 0119:  avg train cost =     3.1713,  avg test cost =     3.3734,  reg penalty =     0.0516
# Epoch 0149:  avg train cost =     3.1670,  avg test cost =     3.3762,  reg penalty =     0.0519
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 152,  end cost: 198.830692
#      ---> best epoch: 75,  best cost: 198.300178
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2517,  avg test cost =     3.3757,  reg penalty =     1.3695
# Epoch 0029:  avg train cost =     3.2259,  avg test cost =     3.2886,  reg penalty =     0.1019
# Epoch 0059:  avg train cost =     3.2200,  avg test cost =     3.2704,  reg penalty =     0.0908
# Epoch 0089:  avg train cost =     3.2181,  avg test cost =     3.2640,  reg penalty =     0.0866
# Epoch 0119:  avg train cost =     3.2157,  avg test cost =     3.2619,  reg penalty =     0.0852
# Epoch 0149:  avg train cost =     3.2140,  avg test cost =     3.2597,  reg penalty =     0.0841
# Epoch 0179:  avg train cost =     3.2139,  avg test cost =     3.2579,  reg penalty =     0.0835
# Epoch 0209:  avg train cost =     3.2116,  avg test cost =     3.2579,  reg penalty =     0.0834
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 193.988404
#      ---> best epoch: 202,  best cost: 193.650501
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 24 [3.27677703 3.25536966 0.         0.         0.         0.        ]
# Epoch 0000:  avg train cost =     3.9957,  avg test cost =     4.1147,  reg penalty =     0.2169
# Epoch 0029:  avg train cost =     3.1864,  avg test cost =     3.4214,  reg penalty =     0.0650
# Epoch 0059:  avg train cost =     3.1577,  avg test cost =     3.3979,  reg penalty =     0.0608
# Epoch 0089:  avg train cost =     3.1468,  avg test cost =     3.3921,  reg penalty =     0.0602
# Epoch 0119:  avg train cost =     3.1377,  avg test cost =     3.3956,  reg penalty =     0.0604
# Epoch 0149:  avg train cost =     3.1334,  avg test cost =     3.3981,  reg penalty =     0.0605
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 150,  end cost: 200.693921
#      ---> best epoch: 97,  best cost: 200.140612
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2251,  avg test cost =     3.3905,  reg penalty =     1.2401
# Epoch 0029:  avg train cost =     3.2033,  avg test cost =     3.2796,  reg penalty =     0.1234
# Epoch 0059:  avg train cost =     3.2011,  avg test cost =     3.2621,  reg penalty =     0.1103
# Epoch 0089:  avg train cost =     3.2009,  avg test cost =     3.2558,  reg penalty =     0.1043
# Epoch 0119:  avg train cost =     3.1984,  avg test cost =     3.2524,  reg penalty =     0.1013
# Epoch 0149:  avg train cost =     3.1973,  avg test cost =     3.2507,  reg penalty =     0.0995
# Epoch 0179:  avg train cost =     3.1972,  avg test cost =     3.2498,  reg penalty =     0.0974
# Epoch 0209:  avg train cost =     3.1952,  avg test cost =     3.2511,  reg penalty =     0.0968
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 194.329582
#      ---> best epoch: 202,  best cost: 193.994892
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 32 [3.27677703 3.25536966 3.2477212  0.         0.         0.        ]
# Epoch 0000:  avg train cost =     4.0371,  avg test cost =     4.1663,  reg penalty =     0.2989
# Epoch 0029:  avg train cost =     3.1693,  avg test cost =     3.4147,  reg penalty =     0.0719
# Epoch 0059:  avg train cost =     3.1382,  avg test cost =     3.3994,  reg penalty =     0.0683
# Epoch 0089:  avg train cost =     3.1249,  avg test cost =     3.4017,  reg penalty =     0.0681
# Epoch 0119:  avg train cost =     3.1157,  avg test cost =     3.4089,  reg penalty =     0.0682
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 136,  end cost: 201.732620
#      ---> best epoch: 61,  best cost: 200.741294
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2188,  avg test cost =     3.3808,  reg penalty =     1.0535
# Epoch 0029:  avg train cost =     3.1975,  avg test cost =     3.2736,  reg penalty =     0.1327
# Epoch 0059:  avg train cost =     3.1940,  avg test cost =     3.2563,  reg penalty =     0.1198
# Epoch 0089:  avg train cost =     3.1928,  avg test cost =     3.2523,  reg penalty =     0.1139
# Epoch 0119:  avg train cost =     3.1906,  avg test cost =     3.2523,  reg penalty =     0.1111
# Epoch 0149:  avg train cost =     3.1894,  avg test cost =     3.2501,  reg penalty =     0.1093
# Epoch 0179:  avg train cost =     3.1891,  avg test cost =     3.2490,  reg penalty =     0.1083
# Epoch 0209:  avg train cost =     3.1872,  avg test cost =     3.2506,  reg penalty =     0.1081
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 194.903956
#      ---> best epoch: 202,  best cost: 194.610590
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 40 [3.27677703 3.25536966 3.2477212  3.24736476 0.         0.        ]
# Epoch 0000:  avg train cost =     4.0216,  avg test cost =     4.1429,  reg penalty =     0.4107
# Epoch 0029:  avg train cost =     3.1555,  avg test cost =     3.4292,  reg penalty =     0.0782
# Epoch 0059:  avg train cost =     3.1224,  avg test cost =     3.4222,  reg penalty =     0.0747
# Epoch 0089:  avg train cost =     3.1053,  avg test cost =     3.4293,  reg penalty =     0.0746
# Epoch 0119:  avg train cost =     3.0961,  avg test cost =     3.4360,  reg penalty =     0.0750
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 128,  end cost: 203.587699
#      ---> best epoch: 48,  best cost: 202.561781
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2215,  avg test cost =     3.3882,  reg penalty =     0.9077
# Epoch 0029:  avg train cost =     3.1870,  avg test cost =     3.2723,  reg penalty =     0.1466
# Epoch 0059:  avg train cost =     3.1835,  avg test cost =     3.2589,  reg penalty =     0.1361
# Epoch 0089:  avg train cost =     3.1818,  avg test cost =     3.2547,  reg penalty =     0.1321
# Epoch 0119:  avg train cost =     3.1789,  avg test cost =     3.2532,  reg penalty =     0.1300
# Epoch 0149:  avg train cost =     3.1771,  avg test cost =     3.2512,  reg penalty =     0.1290
# Epoch 0179:  avg train cost =     3.1771,  avg test cost =     3.2487,  reg penalty =     0.1278
# Epoch 0209:  avg train cost =     3.1746,  avg test cost =     3.2507,  reg penalty =     0.1277
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 196.059346
#      ---> best epoch: 202,  best cost: 195.758046
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 48 [3.27677703 3.25536966 3.2477212  3.24736476 3.24742293 0.        ]
# Epoch 0000:  avg train cost =     3.9895,  avg test cost =     4.1322,  reg penalty =     0.5014
# Epoch 0029:  avg train cost =     3.1435,  avg test cost =     3.4571,  reg penalty =     0.0899
# Epoch 0059:  avg train cost =     3.1090,  avg test cost =     3.4660,  reg penalty =     0.0850
# Epoch 0089:  avg train cost =     3.0943,  avg test cost =     3.4457,  reg penalty =     0.0840
# Epoch 0119:  avg train cost =     3.0843,  avg test cost =     3.4568,  reg penalty =     0.0839
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 130,  end cost: 205.277185
#      ---> best epoch: 61,  best cost: 204.401517
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2208,  avg test cost =     3.4142,  reg penalty =     1.2320
# Epoch 0029:  avg train cost =     3.1967,  avg test cost =     3.2711,  reg penalty =     0.1483
# Epoch 0059:  avg train cost =     3.1904,  avg test cost =     3.2571,  reg penalty =     0.1394
# Epoch 0089:  avg train cost =     3.1877,  avg test cost =     3.2540,  reg penalty =     0.1360
# Epoch 0119:  avg train cost =     3.1858,  avg test cost =     3.2519,  reg penalty =     0.1338
# Epoch 0149:  avg train cost =     3.1842,  avg test cost =     3.2506,  reg penalty =     0.1330
# Epoch 0179:  avg train cost =     3.1838,  avg test cost =     3.2507,  reg penalty =     0.1324
# Epoch 0209:  avg train cost =     3.1819,  avg test cost =     3.2508,  reg penalty =     0.1324
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 222,  end cost: 196.330380
#      ---> best epoch: 216,  best cost: 196.079840
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 60 [3.27677703 3.25536966 3.2477212  3.24736476 3.24742293 3.24848342]

# %%
    # TEST using max-norm for subunits instead of norm
    num_subs=40
    ndn_par = NDNutils.ffnetwork_params( 
        input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid], 
        layer_types=['normal','normal'], ei_layers=[num_subs//2, num_hid//2],
        normalization=[-1,-1], act_funcs=['relu', 'relu'], verbose=False,
        reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
    side_iter = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
    side_iter.set_regularization('glocal', Greg, layer_target=0)
    side_iter.set_regularization('l1', L1reg, layer_target=0)
    side_iter.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=False, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

    LLs = side_iter.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
# Out:
# Epoch 0000:  avg train cost =     4.0463,  avg test cost =     4.1590,  reg penalty =     0.2178
# Epoch 0029:  avg train cost =     3.1932,  avg test cost =     3.3560,  reg penalty =     0.0555
# Epoch 0059:  avg train cost =     3.1519,  avg test cost =     3.3676,  reg penalty =     0.0578
# Epoch 0089:  avg train cost =     3.1338,  avg test cost =     3.3751,  reg penalty =     0.0603
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 115,  end cost: 199.867883
#      ---> best epoch: 28,  best cost: 197.724321
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# Epoch 0000:  avg train cost =     3.2900,  avg test cost =     3.3601,  reg penalty =     1.4317
# Epoch 0029:  avg train cost =     3.2318,  avg test cost =     3.2836,  reg penalty =     0.0908
# Epoch 0059:  avg train cost =     3.2286,  avg test cost =     3.2715,  reg penalty =     0.0858
# Epoch 0089:  avg train cost =     3.2264,  avg test cost =     3.2631,  reg penalty =     0.0837
# Epoch 0119:  avg train cost =     3.2249,  avg test cost =     3.2632,  reg penalty =     0.0815
# Epoch 0149:  avg train cost =     3.2237,  avg test cost =     3.2603,  reg penalty =     0.0802
# Epoch 0179:  avg train cost =     3.2244,  avg test cost =     3.2583,  reg penalty =     0.0795
# Epoch 0209:  avg train cost =     3.2232,  avg test cost =     3.2602,  reg penalty =     0.0790
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 225,  end cost: 193.588449
#      ---> best epoch: 165,  best cost: 193.375063
#
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model

# %%
print(np.mean(LLs), LLsSCsubs[3])
DU.plot_filters(side_iter)
# Out:
# 3.2543762 3.2473647594451904

# %%
plt.plot(LLsSCsubs)
plt.show()

# %%
DU.plot_filters(SCsub_mods[2])

# %%
DU.plot_filters(SCsub_mods[3])

# %%
# Weights between first and second layer
plot_pop_subunit_weights(SCsub_mods[3].networks[0].layers[1].weights, 24)
# Weights to output
DU.scaffold_nonconv_plot(SCsub_mods[3])

# %%
# Check to see if internal-max helps

# %%
## Vary n-inhibition separately
## ASSUME FIRST LAYER 
num_Ehid = 32
sublist=[16, 24, 32, 40, 48]  # num_Ihid
num_subs = 32

Niter = len(sublist)
LLsSCIhid2 = np.zeros(Niter)
SCsubIhid2_mods = []

side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=False,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True

for nn in range(Niter):

    ndn_par = NDNutils.ffnetwork_params( 
        input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_Ehid+sublist[nn]], 
        layer_types=['normal','normal'], ei_layers=[num_subs//2, sublist[nn]],
        normalization=[1,1], act_funcs=['relu', 'relu'], verbose=False,
        reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
    side_iter = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=True, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
    side_iter.set_regularization('glocal', Greg, layer_target=0)
    side_iter.set_regularization('l1', L1reg, layer_target=0)
    side_iter.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=True, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

    LLs = side_iter.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
    LLsSCIhid2[nn] = np.mean(LLs)
    SCsubIhid2_mods.append(side_iter.copy_model())
    print( sublist[nn], LLsSCIhid2)

plt.plot(LLsSCIhid,'r--')
plt.plot(LLsSCIhid2,'b')
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 16 [3.25103474 0.         0.         0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 24 [3.25103474 3.24907517 0.         0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 32 [3.25103474 3.24907517 3.25479126 0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 40 [3.25103474 3.24907517 3.25479126 3.2562604  0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 48 [3.25103474 3.24907517 3.25479126 3.2562604  3.25998354]

# %%
## Vary n-inhibition separately
## ASSUME FIRST LAYER 
num_Ehid = 32
num_Ihid = 32
num_subs = 32

Niter = len(sublist)
LLsSCIhid2 = np.zeros(Niter)
SCsubIhid2_mods = []

side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=False,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True

ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_Ehid+num_Ihid], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2, num_Ehid//2],
    normalization=[1,1], act_funcs=['relu', 'relu'], verbose=False,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
side_iter = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
_ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=True, 
                   learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
side_iter.set_regularization('glocal', Greg, layer_target=0)
side_iter.set_regularization('l1', L1reg, layer_target=0)
side_iter.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
# Out:
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model

# %%
rvals = [1e-6, 1e-4, 0.001, 0.01, 0.1, 1.0, 10]
LLsMI, RmodsMI = NDNutils.reg_path(
    ndn_mod=side_iter, input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi,
    reg_type='max', reg_vals=rvals, ffnet_target=0, layer_target=1, opt_params=adam_params)
plt.plot(LLsMI,'b')
plt.show()
# Out:
# 0 (max = 1e-06): 3.2751162
# 1 (max = 0.0001): 3.2737947
# 2 (max = 0.001): 3.2722814
# 3 (max = 0.01): 3.2716541
# 4 (max = 0.1): 3.2446058
# 5 (max = 1.0): 3.2745547
# 6 (max = 10): 3.2983153

# %%
## Vary n-inhibition separately
## ASSUME FIRST LAYER 
num_Ehid = 16
sublist=[16, 24, 32, 40, 48]  # num_Ihid
num_subs = 32

Niter = len(sublist)
LLsSCIhid = np.zeros(Niter)
SCsubIhid_mods = []

side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['softplus'], verbose=False,
    reg_list={'max':[Mreg0]})
side_par['pos_constraints']=True

for nn in range(Niter):

    ndn_par = NDNutils.ffnetwork_params( 
        input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_Ehid+sublist[nn]], 
        layer_types=['normal','normal'], ei_layers=[num_subs//2, sublist[nn]],
        normalization=[1,1], act_funcs=['relu', 'relu'], verbose=False,
        reg_list={'d2xt':[XTreg], 'l1':[L1reg0], 'glocal':[Greg0]})
    side_iter = NDN.NDN( [ndn_par, side_par], ffnet_out=1, noise_dist='poisson' )
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=True, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )
    side_iter.set_regularization('glocal', Greg, layer_target=0)
    side_iter.set_regularization('l1', L1reg, layer_target=0)
    side_iter.set_regularization('max', MSCreg, ffnet_target=1, layer_target=0)
    _ = side_iter.train(input_data=Xstim, output_data=Robs[valdata,:], train_indxs=Ui, test_indxs=Xi, silent=True, 
                       learning_alg='adam', opt_params=adam_params, output_dir=output_dir )

    LLs = side_iter.eval_models(input_data=Xstim, output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
    LLsSCIhid[nn] = np.mean(LLs)
    SCsubIhid_mods.append(side_iter.copy_model())
    print( sublist[nn], LLsSCIhid)
plt.plot(LLsSCIhid)
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 16 [3.24902034 0.         0.         0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 24 [3.24902034 3.24987435 0.         0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 32 [3.24902034 3.24987435 3.25195789 0.         0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 40 [3.24902034 3.24987435 3.25195789 3.25705194 0.        ]
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# INFO:tensorflow:Restoring parameters from /home/dbutts/V1/pkls/output_dir0/bstmods/best_model
# 48 [3.24902034 3.24987435 3.25195789 3.25705194 3.2521081 ]

# %% [markdown]
# ## Saccadic kernels

# %%
num_saclags = 40
back_shifts = 10

Xsac1 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_on,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xsac2 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_off,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)

# Xsac1 = NDNutils.create_time_embedding(sac_on, [num_saclags, 1, 1], tent_spacing=1)
# Xsac2 = NDNutils.create_time_embedding(sac_off, [num_saclags, 1, 1], tent_spacing=1)
TSreg = 0.0001

# %%
prev_mod = side2b.copy_model()

# %%
# With side model for stimulus
num_subs = 36
num_hid = 24

ndn_par = NDNutils.ffnetwork_params( 
    input_dims=[1,NX2,NX2, num_lags], layer_sizes=[num_subs, num_hid], 
    layer_types=['normal','normal'], ei_layers=[num_subs//2, num_hid//2],
    normalization=[1,1], act_funcs=['relu', 'relu'], verbose=True,
    reg_list={'d2xt':[XTreg], 'l1':[L1reg], 'glocal':[Greg], 'max':[MIreg, MIreg]})
side_par = NDNutils.ffnetwork_params( 
    network_type='side', xstim_n=None, ffnet_n=0, layer_sizes=[NC], 
    layer_types=['normal'], normalization=[-1], act_funcs=['lin'], verbose=True, # changed to lin from softplus
    reg_list={'max':[MSCreg]})
side_par['pos_constraints']=True

# Saccade params that added together
sac1_par = NDNutils.ffnetwork_params( 
    input_dims=[1,1,1, num_saclags], xstim_n=[1],
    layer_sizes=[1, NC], layer_types=['normal', 'normal'], normalization=[1,0], 
    act_funcs=['relu', 'lin'], reg_list={'d2t':[TSreg]})  # make rectified, but don't have to
sac2_par = NDNutils.ffnetwork_params( 
    input_dims=[1,1,1, num_saclags], xstim_n=[2],
    layer_sizes=[1, NC], layer_types=['normal', 'normal'], normalization=[1, 0], act_funcs=['relu', 'lin'],
    reg_list={'d2t':[TSreg]})
comb_par = NDNutils.ffnetwork_params( 
    xstim_n=None, ffnet_n=[1,2,3], layer_sizes=[NC], layer_types=['add'], act_funcs=['softplus'])

sacnim1 = NDN.NDN( [ndn_par, side_par, sac1_par, sac2_par, comb_par], ffnet_out=4, noise_dist='poisson' )
sacnim1.networks[0].layers[0].weights = deepcopy(prev_mod.networks[0].layers[0].weights)
sacnim1.networks[0].layers[0].biases = deepcopy(prev_mod.networks[0].layers[0].biases)
sacnim1.networks[0].layers[1].weights = deepcopy(prev_mod.networks[0].layers[1].weights)
sacnim1.networks[0].layers[1].biases = deepcopy(prev_mod.networks[0].layers[1].biases)
sacnim1.networks[1].layers[0].weights = deepcopy(prev_mod.networks[1].layers[0].weights)

# initially just fit saccade kernels
v2f0 = sacnim1.fit_variables(layers_to_skip=[[0,1],[0]], fit_biases=True)
v2f0[2][1]['biases']=False
v2f0[3][1]['biases']=False
v2f0[4][0]['weights']=False

# Then can fit everything but temporal kernels for stim
v2f = sacnim1.fit_variables(layers_to_skip=[[],[],[],[],[0]], fit_biases=True)
v2f[1][0]['biases']=False
v2f[2][1]['biases']=False
v2f[3][1]['biases']=False

_ = sacnim1.train(
    input_data=[Xstim, Xsac1[valdata,:], Xsac2[valdata,:]], output_data=Robs[valdata,:], 
    train_indxs=Ui, test_indxs=Xi, fit_variables=v2f0, 
    learning_alg='adam', opt_params=adam_params)
_ = sacnim1.train(
    input_data=[Xstim, Xsac1[valdata,:], Xsac2[valdata,:]], output_data=Robs[valdata,:], 
    train_indxs=Ui, test_indxs=Xi, fit_variables=v2f, 
    learning_alg='adam', opt_params=adam_params)

LLS1x = sacnim1.eval_models(input_data=[Xstim, Xsac1[valdata,:], Xsac2[valdata,:]], 
                           output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=False)
LLS1n = sacnim1.eval_models(input_data=[Xstim, Xsac1[valdata,:], Xsac2[valdata,:]], 
                           output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)

print(np.mean(LLS1x), np.mean(LLS1n))
# Out:
# Input dimensions: [1, 24, 24, 10]
# 0: normal (relu):  	[E18/I18] N
# 1: normal (relu):  	[E12/I12] N+
# 0: normal (lin):  	[E58/I0] N
# Input dimensions: [1, 1, 1, 40]
# 0: normal (relu):  	[E1/I0] N
# 1: normal (lin):  	[E58/I0]
# Input dimensions: [1, 1, 1, 40]
# 0: normal (relu):  	[E1/I0] N
# 1: normal (lin):  	[E58/I0]
# 0: add (softplus):  	[E58/I0]
# WARNING:tensorflow:From C:\Users\Jake\.conda\envs\NDN\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Jake\.conda\envs\NDN\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 0000:  avg train cost =     4.4953,  avg test cost =     4.5220,  reg penalty =     0.1752
# Epoch 0029:  avg train cost =     3.2702,  avg test cost =     3.2887,  reg penalty =     0.1751
# Epoch 0059:  avg train cost =     3.2688,  avg test cost =     3.2874,  reg penalty =     0.1751
# Epoch 0089:  avg train cost =     3.2674,  avg test cost =     3.2862,  reg penalty =     0.1751
# Epoch 0119:  avg train cost =     3.2662,  avg test cost =     3.2852,  reg penalty =     0.1751
# Epoch 0149:  avg train cost =     3.2652,  avg test cost =     3.2842,  reg penalty =     0.1751
# Epoch 0179:  avg train cost =     3.2645,  avg test cost =     3.2837,  reg penalty =     0.1751
# Epoch 0209:  avg train cost =     3.2640,  avg test cost =     3.2831,  reg penalty =     0.1751
# Epoch 0239:  avg train cost =     3.2636,  avg test cost =     3.2830,  reg penalty =     0.1751
# Epoch 0269:  avg train cost =     3.2633,  avg test cost =     3.2828,  reg penalty =     0.1751
# Epoch 0299:  avg train cost =     3.2631,  avg test cost =     3.2826,  reg penalty =     0.1751
# Epoch 0329:  avg train cost =     3.2630,  avg test cost =     3.2824,  reg penalty =     0.1751
# Epoch 0359:  avg train cost =     3.2629,  avg test cost =     3.2825,  reg penalty =     0.1751
# Epoch 0389:  avg train cost =     3.2628,  avg test cost =     3.2825,  reg penalty =     0.1751
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 398,  end cost: 200.545108
#      ---> best epoch: 382,  best cost: 200.523326
#
# Epoch 0000:  avg train cost =     3.2353,  avg test cost =     3.2485,  reg penalty =     0.1801
# Epoch 0029:  avg train cost =     3.2111,  avg test cost =     3.2300,  reg penalty =     0.1625
# Epoch 0059:  avg train cost =     3.2096,  avg test cost =     3.2270,  reg penalty =     0.1581
# Epoch 0089:  avg train cost =     3.2086,  avg test cost =     3.2238,  reg penalty =     0.1556
# Epoch 0119:  avg train cost =     3.2074,  avg test cost =     3.2212,  reg penalty =     0.1538
# Epoch 0149:  avg train cost =     3.2071,  avg test cost =     3.2209,  reg penalty =     0.1526
# Epoch 0179:  avg train cost =     3.2070,  avg test cost =     3.2220,  reg penalty =     0.1520
# Epoch 0209:  avg train cost =     3.2058,  avg test cost =     3.2210,  reg penalty =     0.1517
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 232,  end cost: 195.801589
#      ---> best epoch: 202,  best cost: 195.533979
#
# 3.2243042 0.34515706

# %% [markdown]
# This is a pretty good model, according to the LLs. Let's stick with this for saccadic modulation now.

# %%
sacnim1.save_model(dirname+'pkls\\sacstim1.pkl')
# Out:
# Model pickled to C:\Users\Jake\Dropbox\Projects\FreeViewing\Data\pkls\sacstim1.pkl

# %%
# Load model
# Out:
# Model pickled to /home/dbutts/Marmo/pkls/sacstim0.pkl

# %% [markdown]
# ## Predictions for this stimulus, to verify models can produce same STAs

# %%
# Load best models (so far) -- which might already be in memeory

snim0 = NDN.NDN.load_model(dirname+'pkls\\d1231snim0.pkl')
csn0 = NDN.NDN.load_model(dirname+'pkls\\d1231csn0.pkl')
sacmod0 = NDN.NDN.load_model(dirname+'pkls\\sacstim1.pkl')

# %%
# Regenerate stim -- if needed (although need full data)
num_lags = 10
Cindx = crop_indx( NX, range(11, 35), range(15,39) )
XstimAll = NDNutils.create_time_embedding( stim[:, Cindx], [num_lags, NX2, NX2], tent_spacing=1 )

# %%
# Check recalculated LLs Xsac1.shape
LLs0 = snim0.eval_models(input_data=XstimAll[valdata,:], output_data=Robs[valdata,:], 
                         data_indxs=Xi, nulladjusted=True)
LLs1 = csn0.eval_models(input_data=XstimAll[valdata,:], output_data=Robs[valdata,:], 
                        data_indxs=Xi, nulladjusted=True)
LLs2 = sacmod0.eval_models(input_data=[XstimAll[valdata,:], Xsac1[valdata,:], Xsac2[valdata,:]], 
                           output_data=Robs[valdata,:], data_indxs=Xi, nulladjusted=True)
print(np.mean(LLs0), np.mean(LLs1), np.mean(LLs2))
# Out:
# 0.26421976 0.31495982 0.34515703

# %%
# Look at LLs across cells
plt.plot(LLs0,'r--')
plt.plot(LLs1,'b')
plt.plot(LLs2,'g')
plt.show()
# interesting -- note that the extra layers (and sac mod) help only a fraction of cells

# %%
pred0 = snim0.generate_prediction(input_data=XstimAll)
pred1 = csn0.generate_prediction(input_data=XstimAll)
pred2 = sacmod0.generate_prediction(input_data=[XstimAll, Xsac1, Xsac2])

# %%
trange = range(3250,3500) # arbitrary window where most data is valid...
print(len(trange), len(np.intersect1d(trange,valdata)))
fig = plt.figure(figsize=(16, 4))
plt.plot(Robs[trange,cc],'k')
plt.plot(pred0[trange,cc],'r--')
plt.plot(pred1[trange,cc],'b')
plt.plot(pred2[trange,cc],'g')
plt.show()
# Out:
# 250 201

# %% [markdown]
# #### These look like pretty well-modulated responses (!).

# %%
XstimAll = NDNutils.create_time_embedding( stim, [num_lags, NX, NX], tent_spacing=1 )

# Calculate predicted STAs of each neuron
stas = np.reshape(np.matmul(np.transpose(XstimAll[valdata,:]),Robs[valdata,:]), 
                      [NX*NX,num_lags, NC]) / len(valdata)

predstas = np.reshape(np.matmul(np.transpose(XstimAll[valdata,:]),pred1[valdata,:]), 
                      [NX*NX,num_lags, NC]) / len(valdata)
predstas.shape
# Out:
# (1600, 10, 58)

# %%
# Pick one of the good cells to compare
cc = 52
DU.subplot_setup(1,2, row_height=4)
for ilag in range(10):
    plt.subplot(2,10,ilag+1)
    plt.imshow(np.reshape(stas[:,ilag,cc],[NX,NX]), cmap='gray')
    plt.subplot(2,10,10+ilag+1)
    plt.imshow(np.reshape(predstas[:,ilag,cc],[NX,NX]), cmap='gray')
    
plt.show()
print(cc)
stas.shape
# Not sure how closely they should look...
# Out:
# 52
# (1600, 10, 58)

# %% [markdown]
# ## Predictions for RSVP stim (and others)

# %%
# Load RSVP Stimulus
matdat = sio.loadmat(dirname+'L20191231_FixRsvpStimL.mat')
Robs4 = matdat['Robs'].copy()
frameTimes4 = matdat['frameTimes'].copy()
valdat4 = matdat['valdata'].copy()
labels4 = matdat['labels'].copy()
valid4 = np.intersect1d(np.where(valdat4[:,0] == 1)[0], np.where(labels4[:,0] == 1)[0])
slist4 = matdat['slist'].astype(int)
ets4 = matdat['eyeAtFrame']
NT4 = Robs4.shape[0]

matdat = sio.loadmat(dirname+'L20191231_FixRsvpStim_Cstim.mat')
stim4 = matdat['Cstim'].copy()

# Load BackImage Stimulus
matdat = sio.loadmat(dirname+'L20191231_BackImageL.mat')
Robs5 = matdat['Robs'].copy()
frameTimes5 = matdat['frameTimes'].copy()
valdat5 = matdat['valdata'].copy()
labels5 = matdat['labels'].copy()
valid5 = np.intersect1d(np.where(valdat5[:,0] == 1)[0], np.where(labels5[:,0] == 1)[0])
slist5 = matdat['slist'].astype(int)
ets5 = matdat['eyeAtFrame']
NT5 = Robs5.shape[0]

matdat = sio.loadmat(dirname+'L20191231_BackImage_Cstim.mat')
stim5 = matdat['Cstim'].copy()

#
# Process saccades -- just store sacc offsets as delta functions
sac_on4, sac_off4 = np.zeros([NT4,1], dtype='float32'), np.zeros([NT4,1], dtype='float32')
sac_on5, sac_off5 = np.zeros([NT5,1], dtype='float32'), np.zeros([NT5,1], dtype='float32')
for nn in range(slist4.shape[0]):
    sac_on4[slist4[nn,0]-1] = 1.0
    sac_off4[slist4[nn,1]-1] = 1.0
    
for nn in range(slist5.shape[0]):
    sac_on5[slist5[nn,0]-1] = 1.0
    sac_off5[slist5[nn,1]-1] = 1.0

# %%
# Crop and create design matrix
Cindx = crop_indx( NX, range(11, 35), range(15,39) )
NX2 = np.sqrt(len(Cindx)).astype(int)
Xstim4 = NDNutils.create_time_embedding( stim4[:, Cindx], [num_lags, NX2, NX2], tent_spacing=1 )
Xstim5 = NDNutils.create_time_embedding( stim5[:, Cindx], [num_lags, NX2, NX2], tent_spacing=1 )

Xsac14 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_on4,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xsac24 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_off4,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xsac15 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_on5,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xsac25 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_off5,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)

# %%
Xsac15 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_on5,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xsac25 = NDNutils.create_time_embedding(NDNutils.shift_mat_zpad(sac_off5,-back_shifts,dim=0), [num_saclags, 1, 1], tent_spacing=1)
Xstim4.shape
# Out:
# (5275, 5760)

# %%
Robs4s = NDNutils.shift_mat_zpad(Robs4[:,valcell], -1, dim=0)
# Check recalculated LLs Xsac1.shape
LLs0rsvp = snim0.eval_models(input_data=Xstim4, output_data=Robs4s, nulladjusted=True)
LLs1rsvp = csn0.eval_models(input_data=Xstim4, output_data=Robs4s, nulladjusted=True)
LLs2rsvp = sacmod0.eval_models(input_data=[Xstim4, Xsac14, Xsac24], 
                           output_data=Robs4s, nulladjusted=True)
print(np.mean(LLs0rsvp), np.mean(LLs1rsvp), np.mean(LLs2rsvp))

Robs5s = NDNutils.shift_mat_zpad(Robs5[:,valcell], -1, dim=0)
# Check recalculated LLs Xsac1.shape
LLs0bi = snim0.eval_models(input_data=Xstim5, output_data=Robs5s, nulladjusted=True)
LLs1bi = csn0.eval_models(input_data=Xstim5, output_data=Robs5s, nulladjusted=True)
LLs2bi = sacmod0.eval_models(input_data=[Xstim5, Xsac15, Xsac25], 
                           output_data=Robs5s, nulladjusted=True)
print(np.mean(LLs0bi), np.mean(LLs1bi), np.mean(LLs2bi))
# Out:
# -103.57284 -18.935524 -37.69516
# -63.39119 -9.123022 -19.5091

# %%
NT4 = Xstim4.shape[0]

# %%
csn1 = csn0.copy_model()
Uinds4, Xinds4 = NDNutils.generate_xv_folds(NT4, num_blocks=2)
_=csn1.train(input_data=Xstim4, output_data=Robs4[:,valcell], train_indxs=Uinds4, test_indxs=Xinds4, silent=False, 
                       learning_alg='adam', opt_params=adam_params)

# %%
DU.plot_filters(csn1)

# %%
csn2 = csn1.copy_model()
NT5 = Robs5.shape[0]
Uinds5, Xinds5 = NDNutils.generate_xv_folds(NT5, num_blocks=2)
_=csn2.train(input_data=Xstim5, output_data=Robs5[:,valcell], train_indxs=Uinds5, test_indxs=Xinds5, silent=False, 
                       learning_alg='adam', opt_params=adam_params)
# Out:
# Epoch 0000:  avg train cost =     4.7563,  avg test cost =     5.1704,  reg penalty =     0.1652
# Epoch 0029:  avg train cost =     2.6952,  avg test cost =     2.9606,  reg penalty =     0.1149
# Epoch 0059:  avg train cost =     2.6671,  avg test cost =     2.9341,  reg penalty =     0.0949
# Epoch 0089:  avg train cost =     2.6580,  avg test cost =     2.9202,  reg penalty =     0.0864
# Epoch 0119:  avg train cost =     2.6522,  avg test cost =     2.9197,  reg penalty =     0.0835
#
# *** early stop criteria met...stopping train now...
#      ---> number of epochs used: 141,  end cost: 177.394016
#      ---> best epoch: 110,  best cost: 173.719603

# %%
DU.plot_filters(csn1)

# %%
pred0rsvp = snim0.generate_prediction(input_data=Xstim4)
pred1rsvp = csn1.generate_prediction(input_data=Xstim4)
pred2rsvp = sacmod0.generate_prediction(input_data=[Xstim4, Xsac14, Xsac24])

pred0bi = snim0.generate_prediction(input_data=Xstim5)
pred1bi = csn1.generate_prediction(input_data=Xstim5)
pred2bi = sacmod0.generate_prediction(input_data=[Xstim5, Xsac15, Xsac25])

# %%
# Export Model
snim0.matlab_export(dirname + "export1231_snim0")
csn0.matlab_export(dirname + "export1231_csn0")
csn1.matlab_export(dirname + "export1231_csn1")
sacmod0.matlab_export(dirname + "export1231_sacmod0")

# %%
# save predictions
outdat = dict([('pred0All', pred0),
    ('pred1All', pred1), 
    ('pred2All', pred2), 
    ('RobsAll', Robs),
    ('frameTimesAll', frameTimesAll),
    ('sac_onAll', sac_on),
    ('sac_offAll', sac_off),
    ('valdataAll',valdata),
    ('pred0Rsvp', pred0rsvp),
    ('pred1Rsvp', pred1rsvp), 
    ('pred2Rsvp', pred2rsvp), 
    ('RobsRsvp', Robs4[:,valcell]),
    ('frameTimesRsvp', frameTimes4),
    ('sac_onRsvp', sac_on4),
    ('sac_offRsvp', sac_off4),
    ('valdataRsvp',valdat4),
    ('pred0Bi', pred0bi),
    ('pred1Bi', pred1bi), 
    ('pred2Bi', pred2bi), 
    ('RobsBi', Robs5[:,valcell]),
    ('frameTimesBi', frameTimes5),
    ('sac_onBi', sac_on5),
    ('sac_offBi', sac_off5),
    ('valdataBi',valdat5)])

sio.savemat(dirname + "model1231_predictions2.mat", outdat)

# %%
sio.savemat(dirname + "model_stas.mat", dict([('predstas', predstas), ('stas', stas)]))

# %%
csn0.graph
